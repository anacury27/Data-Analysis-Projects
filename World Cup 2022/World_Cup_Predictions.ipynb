# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fifa = pd.read_csv('/content/drive/MyDrive/Applied Data Science/Fifa Worldcup 2022 (1).csv')

# %%
fifa
# Out:
#      Sl. No  Match No.            Team      Against Group  Goal  \
# 0         1          1           Qatar      Ecuador     A     0
# 1         2          1         Ecuador        Qatar     A     2
# 2         3          2         England         Iran     B     6
# 3         4          2            Iran      England     B     2
# 4         5          3         Senegal  Netherlands     A     0
# ..      ...        ...             ...          ...   ...   ...
# 107     108         54  Korea Republic       Brazil     H     1
# 108     109         55         Morocco        Spain     F     0
# 109     110         55           Spain      Morocco     E     0
# 110     111         56        Portugal  Switzerland     H     6
# 111     112         56     Switzerland     Portugal     G     1
#
#      Possession (%)  Inside Penalty Area  Outside Penalty Area  Assists  ...  \
# 0                40                    0                     0        0  ...
# ...

# %%
(fifa.groupby('Team')['Goal'].sum()>5)
# Out:
# Team
# Argentina          True
# Australia         False
# Belgium           False
# Brazil             True
# Cameroon          False
# Canada            False
# Costa Rica        False
# Croatia           False
# Denmark           False
# Ecuador           False
# England            True
# France             True
# Germany            True
# Ghana             False
# Iran              False
# Japan             False
# Korea Republic    False
# Mexico            False
# Morocco           False
# Netherlands        True
# Poland            False
# Portugal           True
# Qatar             False
# Saudi Arabia      False
# Senegal           False
# Serbia            False
# Spain              True
# Switzerland       False
# Tunisia           False
# United States     False
# Uruguay           False
# Wales             False
# Name: Goal, dtype: bool

# %%
(fifa.groupby('Team')['Crosses Completed'].sum()).sort_values(ascending=False).head(1)
# Out:
# Team
# Croatia    43
# Name: Crosses Completed, dtype: int64

# %%
fifa['% Line Breaks'] = ((fifa['Completed Line Breaks']/fifa['Attempted Line Breaks'])*100)

# %%
fifa.loc[fifa['% Line Breaks'].idxmax()].head(3)
# Out:
# Sl. No              78
# Match No.           39
# Team         Argentina
# Name: 77, dtype: object

# %%
fifa.dtypes
# Out:
# Sl. No                               int64
# Match No.                            int64
# Team                                object
# Against                             object
# Group                               object
# Goal                                 int64
# Possession (%)                       int64
# Inside Penalty Area                  int64
# Outside Penalty Area                 int64
# Assists                              int64
# Total Attempts                       int64
# On Target                            int64
# Off Target                           int64
# Target in Penalty                    int64
# Target from Outside                  int64
# Left Channel                         int64
# Left Inside Channel                  int64
# Central Channel                      int64
# Right Inside Channel                 int64
# Right Channel                        int64
# Receptions MD                        int64
# Receptions D                         int64
# ...

# %%
fifa.loc[fifa['Group'].isin(['A']),'Free Kicks'].mean().round(2)
# Out:
# 15.43
