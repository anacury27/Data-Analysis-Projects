# %%
import pandas as pd

# %%
covid=pd.read_csv('/content/drive/MyDrive/Applied Data Science/responses.csv')

# %%
performance=pd.read_csv('/content/drive/MyDrive/Applied Data Science/student-por.csv')

# %%
covid
# Out:
#                  Category Country State  Age  Gender Before-Environment  \
# 0   SchoolCollegeTraining      US    TX   14    Male           Physical
# 1   SchoolCollegeTraining      US    MD   13    Male           Physical
# 2              Homeschool      US    TX   16  Female            Virtual
# 3   SchoolCollegeTraining      US    GA   17    Male           Physical
# 4   SchoolCollegeTraining      GB   NaN   14    Male           Physical
# 5   SchoolCollegeTraining      US    WV   17    Male           Physical
# 6   SchoolCollegeTraining      US    MO   18  Female           Physical
# 7   SchoolCollegeTraining      US    PA   17    Male           Physical
# 8              Homeschool      US    IL   16  Female             Hybrid
# 9   SchoolCollegeTraining      US    MN   15  Female           Physical
# 10             Homeschool      US    TX   18    Male             Hybrid
# 11             Homeschool      US    FL   15  Female           Physical
# 12             Homeschool      US    FL   14  Female            Virtual
# 13  SchoolCollegeTraining      US    FL   15  Female           Physical
# 14  SchoolCollegeTraining      US    FL   15  Female           Physical
# 15  SchoolCollegeTraining      US    CO   14  Female           Physical
# 16  SchoolCollegeTraining      US    WA   15  Female           Physical
# 17  SchoolCollegeTraining      US    UT   17  Female           Physical
# 18  SchoolCollegeTraining      US    TX   14    Male           Physical
# 19  SchoolCollegeTraining      US    WA   14   Other           Physical
# 20  SchoolCollegeTraining      US    MI   16  Female           Physical
# 21  SchoolCollegeTraining      GB   NaN   20    Male           Physical
# 22  SchoolCollegeTraining      CA   NaN   15     NaN           Physical
# 23  SchoolCollegeTraining      GB   NaN   17    Male           Physical
# 24  SchoolCollegeTraining      US    CA   17    Male           Physical
# 25  SchoolCollegeTraining      US    TX   17   Other           Physical
# 26  SchoolCollegeTraining      US    IL   15    Male           Physical
# 27  SchoolCollegeTraining      GB   NaN   17  Female           Physical
# 28  SchoolCollegeTraining      RS   NaN   17  Female           Physical
# 29  SchoolCollegeTraining      US    GA   15  Female           Physical
# 30  SchoolCollegeTraining      US    IN   16     NaN           Physical
# 31  SchoolCollegeTraining      GB   NaN   15    Male           Physical
# 32  SchoolCollegeTraining      DE   NaN   21    Male           Physical
# 33  SchoolCollegeTraining      US    PA   16    Male           Physical
# 34  SchoolCollegeTraining      GB   NaN   15    Male           Physical
# 35  SchoolCollegeTraining      US    AZ   19  Female             Hybrid
# 36  SchoolCollegeTraining      US    NY   16     NaN           Physical
# 37  SchoolCollegeTraining      MY   NaN   20  Female           Physical
# 38  SchoolCollegeTraining      BD   NaN   22  Female            Virtual
# 39  SchoolCollegeTraining      FR   NaN   21  Female           Physical
#
#     Before-ClassworkStress  Before-HomeworkStress  Before-HomeworkHours  \
# 0                        1                      3                   2.0
# 1                        5                      4                   2.0
# 2                        1                      3                  10.0
# 3                        4                      4                   6.0
# 4                        3                      4                   4.0
# 5                        1                      1                   3.0
# 6                        2                      3                   3.0
# 7                        1                      3                   3.0
# 8                        3                      3                   3.0
# 9                        2                      2                   1.0
# 10                       3                      2                   4.0
# 11                       2                      3                   4.0
# 12                       1                      1                   3.0
# 13                       2                      2                   4.0
# 14                       2                      3                   5.0
# 15                       5                      4                   9.0
# 16                       0                      0                   0.0
# 17                       3                      5                   3.5
# 18                       4                      4                   1.0
# 19                       2                      5                   2.0
# 20                       3                      5                   4.0
# 21                       3                      4                   3.0
# 22                       1                      1                   1.0
# 23                       2                      3                   1.0
# 24                       4                      5                   5.0
# 25                       1                      3                   3.0
# 26                       2                      3                   0.0
# 27                       4                      4                   2.5
# 28                       2                      3                   0.0
# 29                       2                      1                   0.0
# 30                       1                      2                   1.0
# 31                       3                      4                   1.0
# 32                       2                      5                   4.0
# 33                       2                      2                   1.0
# 34                       3                      4                   2.0
# 35                       1                      4                   2.0
# 36                       6                      4                   2.0
# 37                       2                      2                   3.0
# 38                       2                      1                   1.0
# 39                       2                      3                   3.0
#
#    Now-Environment  Now-ClassworkStress  Now-HomeworkStress  \
# 0          Virtual                    3                   5
# 1          Virtual                    3                   5
# 2          Virtual                    3                   5
# 3         Physical                    5                   1
# 4         Physical                    5                   5
# 5          Virtual                    5                   6
# 6          Virtual                    3                   5
# 7          Virtual                    5                   5
# 8           Hybrid                    2                   4
# 9          Virtual                    1                   2
# 10         Virtual                    4                   3
# 11         Virtual                    4                   5
# 12         Virtual                    5                   6
# 13         Virtual                    2                   3
# 14         Virtual                    6                   6
# 15         Virtual                    6                   5
# 16         Virtual                    3                   3
# 17        Physical                    3                   2
# 18         Virtual                    4                   4
# 19         Virtual                    4                   5
# 20         Virtual                    2                   4
# 21         Virtual                    3                   5
# 22          Hybrid                    2                   5
# 23          Hybrid                    3                   5
# 24         Virtual                    1                   5
# 25         Virtual                    3                   5
# 26          Hybrid                    4                   3
# 27          Hybrid                    6                   6
# 28         Virtual                    1                   1
# 29          Hybrid                    5                   5
# 30         Virtual                    6                   6
# 31          Hybrid                    5                   5
# 32         Virtual                    2                   6
# 33         Virtual                    4                   4
# 34        Physical                    5                   4
# 35         Virtual                    2                   5
# 36        Physical                    6                   5
# 37         Virtual                    4                   4
# 38         Virtual                    3                   3
# 39         Virtual                    2                   4
#
#     Now-HomeworkHours  FamilyRelationships  FriendRelationships
# 0                 4.5                    2                   -1
# 1                 2.5                    1                   -2
# 2                15.0                    1                   -1
# 3                 6.0                    0                   -2
# 4                 6.0                    0                    1
# 5                14.0                    2                   -2
# 6                 6.0                   -2                   -1
# 7                 5.0                    0                   -3
# 8                 1.0                   -3                    2
# 9                 5.0                    1                   -1
# 10                4.0                    0                   -2
# 11                8.0                   -1                   -1
# 12                5.0                    0                    2
# 13                7.0                    0                    2
# 14                7.0                   -1                   -1
# 15               10.0                   -1                   -3
# 16                6.0                    2                    0
# 17                1.5                    0                    0
# 18                2.0                    1                    2
# 19                4.0                   -1                   -3
# 20                4.0                    1                   -1
# 21                5.0                   -1                    0
# 22                8.0                    0                    2
# 23                2.0                    0                    0
# 24                2.0                   -1                   -3
# 25                4.0                    1                   -2
# 26                2.0                   -1                    1
# 27                5.0                   -2                   -1
# 28                2.0                    0                    0
# 29                3.0                    3                   -3
# 30                2.0                    1                   -3
# 31                1.0                   -1                    2
# 32                6.0                   -1                    1
# 33                1.0                    1                    2
# 34                3.0                    1                    2
# 35                5.0                    0                    0
# 36                1.0                    1                   -3
# 37                4.0                    0                   -1
# 38                1.0                    2                    0
# 39                4.0                    1                   -1

# %%
performance
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
performance.rename(columns = {'age' : 'Age'}, inplace = True)

# %%
performance
# Out:
#     school sex  Age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
performance = performance.join(covid.set_index('Age'), on = 'Age')

# %%
performance
# Out:
#     school sex  Age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... Before-Environment Before-ClassworkStress  Before-HomeworkStress  \
# 0    ...           Physical                      2                      3
# 0    ...             Hybrid                      3                      2
# 1    ...           Physical                      4                      4
# 1    ...           Physical                      1                      1
# 1    ...           Physical                      1                      3
# ..   ...                ...                    ...                    ...
# 647  ...           Physical                      1                      3
# 647  ...           Physical                      4                      4
# 647  ...           Physical                      2                      3
# 648  ...           Physical                      2                      3
# 648  ...             Hybrid                      3                      2
#
#      Before-HomeworkHours  Now-Environment Now-ClassworkStress  \
# 0                     3.0          Virtual                   3
# 0                     4.0          Virtual                   4
# 1                     6.0         Physical                   5
# 1                     3.0          Virtual                   5
# 1                     3.0          Virtual                   5
# ..                    ...              ...                 ...
# 647                   3.0          Virtual                   3
# 647                   2.5           Hybrid                   6
# 647                   0.0          Virtual                   1
# 648                   3.0          Virtual                   3
# 648                   4.0          Virtual                   4
#
#     Now-HomeworkStress Now-HomeworkHours FamilyRelationships  \
# 0                    5               6.0                  -2
# 0                    3               4.0                   0
# 1                    1               6.0                   0
# 1                    6              14.0                   2
# 1                    5               5.0                   0
# ..                 ...               ...                 ...
# 647                  5               4.0                   1
# 647                  6               5.0                  -2
# 647                  1               2.0                   0
# 648                  5               6.0                  -2
# 648                  3               4.0                   0
#
#     FriendRelationships
# 0                    -1
# 0                    -2
# 1                    -2
# 1                    -2
# 1                    -3
# ..                  ...
# 647                  -2
# 647                  -1
# 647                   0
# 648                  -1
# 648                  -2
#
# [4122 rows x 47 columns]

# %%
performance.drop(columns = ['school','Gender','Category','Before-Environment','Country','FamilyRelationships','famsize', 'reason','guardian','traveltime','studytime','failures','schoolsup','famsup','paid','activities','nursery','higher','internet','romantic','famrel','freetime','goout','Dalc','Walc','health','absences','G1','G2','G3'],inplace=True)

# %%
performance
# Out:
#     sex  Age address Pstatus  Medu  Fedu      Mjob      Fjob State  \
# 0     F   18       U       A     4     4   at_home   teacher    MO
# 0     F   18       U       A     4     4   at_home   teacher    TX
# 1     F   17       U       T     1     1   at_home     other    GA
# 1     F   17       U       T     1     1   at_home     other    WV
# 1     F   17       U       T     1     1   at_home     other    PA
# ..   ..  ...     ...     ...   ...   ...       ...       ...   ...
# 647   M   17       U       T     3     1  services  services    TX
# 647   M   17       U       T     3     1  services  services   NaN
# 647   M   17       U       T     3     1  services  services   NaN
# 648   M   18       R       T     3     2  services     other    MO
# 648   M   18       R       T     3     2  services     other    TX
#
#      Before-ClassworkStress  Before-HomeworkStress  Before-HomeworkHours  \
# 0                         2                      3                   3.0
# 0                         3                      2                   4.0
# 1                         4                      4                   6.0
# 1                         1                      1                   3.0
# 1                         1                      3                   3.0
# ..                      ...                    ...                   ...
# 647                       1                      3                   3.0
# 647                       4                      4                   2.5
# 647                       2                      3                   0.0
# 648                       2                      3                   3.0
# 648                       3                      2                   4.0
#
#     Now-Environment  Now-ClassworkStress  Now-HomeworkStress  \
# 0           Virtual                    3                   5
# 0           Virtual                    4                   3
# 1          Physical                    5                   1
# 1           Virtual                    5                   6
# 1           Virtual                    5                   5
# ..              ...                  ...                 ...
# 647         Virtual                    3                   5
# 647          Hybrid                    6                   6
# 647         Virtual                    1                   1
# 648         Virtual                    3                   5
# 648         Virtual                    4                   3
#
#      Now-HomeworkHours  FriendRelationships
# 0                  6.0                   -1
# 0                  4.0                   -2
# 1                  6.0                   -2
# 1                 14.0                   -2
# 1                  5.0                   -3
# ..                 ...                  ...
# 647                4.0                   -2
# 647                5.0                   -1
# 647                2.0                    0
# 648                6.0                   -1
# 648                4.0                   -2
#
# [4122 rows x 17 columns]

# %%
performance['Increased Stress'] = ((performance['Now-HomeworkStress']-performance['Before-HomeworkStress'])+(performance['Now-ClassworkStress']-performance['Before-ClassworkStress']))/2

# %%
performance
# Out:
#     sex  Age address Pstatus  Medu  Fedu      Mjob      Fjob State  \
# 0     F   18       U       A     4     4   at_home   teacher    MO
# 0     F   18       U       A     4     4   at_home   teacher    TX
# 1     F   17       U       T     1     1   at_home     other    GA
# 1     F   17       U       T     1     1   at_home     other    WV
# 1     F   17       U       T     1     1   at_home     other    PA
# ..   ..  ...     ...     ...   ...   ...       ...       ...   ...
# 647   M   17       U       T     3     1  services  services    TX
# 647   M   17       U       T     3     1  services  services   NaN
# 647   M   17       U       T     3     1  services  services   NaN
# 648   M   18       R       T     3     2  services     other    MO
# 648   M   18       R       T     3     2  services     other    TX
#
#      Before-ClassworkStress  Before-HomeworkStress  Before-HomeworkHours  \
# 0                         2                      3                   3.0
# 0                         3                      2                   4.0
# 1                         4                      4                   6.0
# 1                         1                      1                   3.0
# 1                         1                      3                   3.0
# ..                      ...                    ...                   ...
# 647                       1                      3                   3.0
# 647                       4                      4                   2.5
# 647                       2                      3                   0.0
# 648                       2                      3                   3.0
# 648                       3                      2                   4.0
#
#     Now-Environment  Now-ClassworkStress  Now-HomeworkStress  \
# 0           Virtual                    3                   5
# 0           Virtual                    4                   3
# 1          Physical                    5                   1
# 1           Virtual                    5                   6
# 1           Virtual                    5                   5
# ..              ...                  ...                 ...
# 647         Virtual                    3                   5
# 647          Hybrid                    6                   6
# 647         Virtual                    1                   1
# 648         Virtual                    3                   5
# 648         Virtual                    4                   3
#
#      Now-HomeworkHours  FriendRelationships  Increased Stress
# 0                  6.0                   -1               1.5
# 0                  4.0                   -2               1.0
# 1                  6.0                   -2              -1.0
# 1                 14.0                   -2               4.5
# 1                  5.0                   -3               3.0
# ..                 ...                  ...               ...
# 647                4.0                   -2               2.0
# 647                5.0                   -1               2.0
# 647                2.0                    0              -1.5
# 648                6.0                   -1               1.5
# 648                4.0                   -2               1.0
#
# [4122 rows x 18 columns]

# %%
performance.groupby('Now-Environment')['Increased Stress'].mean()
# Out:
# Now-Environment
# Hybrid      1.605799
# Physical   -0.381762
# Virtual     1.542335
# Name: Increased Stress, dtype: float64

# %%
performance.sort_values('Increased Stress',ascending=False).count()
# Out:
# sex                       4122
# Age                       4122
# address                   4122
# Pstatus                   4122
# Medu                      4122
# Fedu                      4122
# Mjob                      4122
# Fjob                      4122
# State                     3232
# Before-ClassworkStress    4122
# Before-HomeworkStress     4122
# Before-HomeworkHours      4122
# Now-Environment           4122
# Now-ClassworkStress       4122
# Now-HomeworkStress        4122
# Now-HomeworkHours         4122
# FriendRelationships       4122
# Increased Stress          4122
# dtype: int64

# %%
performance.groupby('State')['Increased Stress'].describe().loc[:,['max','min','mean']]
# Out:
#        max  min      mean
# State
# AZ     1.0  1.0  1.000000
# CA    -1.5 -1.5 -1.500000
# FL     3.5  0.5  2.000000
# GA     3.5 -1.0  0.731959
# IL     1.0  0.0  0.387543
# IN     4.5  4.5  4.500000
# MI    -1.0 -1.0 -1.000000
# MN    -0.5 -0.5 -0.500000
# MO     1.5  1.5  1.500000
# NY     0.5  0.5  0.500000
# PA     3.0  2.0  2.502809
# TX     2.0  1.0  1.717742
# UT    -1.5 -1.5 -1.500000
# WA     3.0  3.0  3.000000
# WV     4.5  4.5  4.500000

# %%
performance.groupby('Mjob')['Increased Stress'].mean().sort_values(ascending=False)
# Out:
# Mjob
# health      1.323034
# teacher     1.321888
# services    1.296067
# at_home     1.232368
# other       1.210396
# Name: Increased Stress, dtype: float64

# %%
performance.groupby('Fjob')['Increased Stress'].mean().sort_values(ascending=False)
# Out:
# Fjob
# health      1.444118
# services    1.314348
# teacher     1.278455
# other       1.223094
# at_home     1.136015
# Name: Increased Stress, dtype: float64

# %%
performance.groupby('State')['Now-Environment'].value_counts().sort_values(ascending=False)
# Out:
# State  Now-Environment
# TX     Virtual            496
# PA     Virtual            356
# FL     Virtual            336
# IL     Hybrid             289
# CA     Virtual            179
# GA     Physical           179
# UT     Physical           179
# WV     Virtual            179
# IN     Virtual            177
# MI     Virtual            177
# NY     Physical           177
# MO     Virtual            140
# GA     Hybrid             112
# MN     Virtual            112
# WA     Virtual            112
# AZ     Virtual             32
# Name: Now-Environment, dtype: int64

# %%
performance.groupby('State')['Increased Stress'].count().mean()
# Out:
# 215.46666666666667

# %%
performance.groupby('State')['Increased Stress'].mean().sort_values(ascending=False).plot.barh(stacked=True);

# %%
performance.sort_values('Medu',ascending=False).drop_duplicates('Medu').loc[:,['Medu','Increased Stress']]
# Out:
#      Medu  Increased Stress
# 0       4               1.5
# 306     3               1.0
# 78      2               3.0
# 548     1               3.0
# 281     0               0.0

# %%
performance.sort_values('Medu',ascending=False).drop_duplicates('Medu').loc[:,['Medu','Increased Stress']].plot.barh(x='Increased Stress',y='Medu')

# %%
performance[(performance['sex']=='F')&(performance['address']=='R')].groupby('State')['Increased Stress'].mean().sort_values(ascending=False)
# Out:
# State
# IN    4.500000
# WV    4.500000
# WA    3.000000
# PA    2.537313
# FL    2.000000
# TX    1.736264
# MO    1.500000
# AZ    1.000000
# GA    0.754237
# NY    0.500000
# IL    0.425926
# MN   -0.500000
# MI   -1.000000
# CA   -1.500000
# UT   -1.500000
# Name: Increased Stress, dtype: float64

# %%
performance[(performance['sex']=='F')&(performance['address']=='U')].groupby('State')['Increased Stress'].mean().sort_values(ascending=False)
# Out:
# State
# IN    4.500000
# WV    4.500000
# WA    3.000000
# PA    2.509934
# FL    2.000000
# TX    1.715640
# MO    1.500000
# AZ    1.000000
# NY    0.500000
# GA    0.378378
# IL    0.314815
# MN   -0.500000
# MI   -1.000000
# CA   -1.500000
# UT   -1.500000
# Name: Increased Stress, dtype: float64

# %%
performance[(performance['sex']=='M')&(performance['address']=='R')].groupby('State')['Increased Stress'].mean().sort_values(ascending=False)
# Out:
# State
# IN    4.500000
# WV    4.500000
# WA    3.000000
# PA    2.571429
# FL    2.000000
# TX    1.711864
# MO    1.500000
# AZ    1.000000
# NY    0.500000
# IL    0.357143
# GA    0.323529
# MN   -0.500000
# MI   -1.000000
# CA   -1.500000
# UT   -1.500000
# Name: Increased Stress, dtype: float64

# %%
performance[(performance['sex']=='M')&(performance['address']=='U')].groupby('State')['Increased Stress'].mean().sort_values(ascending=False)
# Out:
# State
# IN    4.500000
# WV    4.500000
# WA    3.000000
# PA    2.437500
# FL    2.000000
# TX    1.711111
# MO    1.500000
# GA    1.327586
# AZ    1.000000
# NY    0.500000
# IL    0.454545
# MN   -0.500000
# MI   -1.000000
# CA   -1.500000
# UT   -1.500000
# Name: Increased Stress, dtype: float64

# %%
performance.groupby('sex')['FriendRelationships'].mean().sort_values(ascending=False)
# Out:
# sex
# M   -0.673888
# F   -0.817730
# Name: FriendRelationships, dtype: float64

# %%
performance.groupby('Fjob')['FriendRelationships'].mean().sort_values(ascending=False)
# Out:
# Fjob
# health     -0.405882
# services   -0.647826
# teacher    -0.723577
# other      -0.818736
# at_home    -0.973180
# Name: FriendRelationships, dtype: float64

# %%
performance.groupby('Mjob')['FriendRelationships'].mean().sort_values(ascending=False)
# Out:
# Mjob
# health     -0.603933
# teacher    -0.656652
# services   -0.684270
# at_home    -0.799748
# other      -0.841584
# Name: FriendRelationships, dtype: float64

# %%
performance.groupby('Now-Environment')['FriendRelationships'].mean().head().plot(kind='bar', ylabel = 'FriendRelationships ', title = 'Impact On Friendships')

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=performance, kind="bar",
    x="Now-Environment", y="FriendRelationships", hue="sex",
     palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Environment", "Friendships")
g.legend.set_title("")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=performance, kind="bar",
    x="Now-Environment", y="FriendRelationships", hue="Age",
     palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Environment", "Friendships")
g.legend.set_title("")
